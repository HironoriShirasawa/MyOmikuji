# %% [markdown]
# <a href="https://colab.research.google.com/github/HironoriShirasawa/MyOmikuji/blob/master/%E8%BB%8A%E3%81%AE%E4%BE%A1%E6%A0%BC%E5%88%86%E6%9E%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io

# %%
input_data = pd.read_csv('CarPrice_Assignment.csv')
input_data.head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# ...

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
input_data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
print('価格の平均:',input_data.price.mean())
print('価格の中央値:',input_data.price.median())
print('価格の分散:',input_data.price.var())
print('価格の標準偏差:',input_data.price.std())
print('価格の最大値:',input_data.price.max())
print('価格の最小値:',input_data.price.min())
# Out:
# 価格の平均: 13276.710570731706
# 価格の中央値: 10295.0
# 価格の分散: 63821761.57839796
# 価格の標準偏差: 7988.85233174315
# 価格の最大値: 45400.0
# 価格の最小値: 5118.0

# %%
print(input_data.groupby('doornumber')['price'].mean())
print(input_data.groupby('doornumber')['price'].median())
print(input_data.groupby('doornumber')['price'].var())
print(input_data.groupby('doornumber')['price'].std())
print(input_data.groupby('doornumber')['price'].max())
print(input_data.groupby('doornumber')['price'].min())
# Out:
# doornumber
# four    13501.152174
# two     12989.924078
# Name: price, dtype: float64
# doornumber
# four    10898.0
# two      9927.0
# Name: price, dtype: float64
# doornumber
# four    5.385059e+07
# two     7.716266e+07
# Name: price, dtype: float64
# doornumber
# four    7338.296321
# two     8784.227805
# Name: price, dtype: float64
# doornumber
# four    40960.0
# two     45400.0
# Name: price, dtype: float64
# doornumber
# four    6229.0
# two     5118.0
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt
#価格についてヒストグラムを描く
plt.hist(input_data.price)
plt.xlabel('price')
plt.ylabel('count')
plt.grid(True)

# %%
plt.boxplot(input_data.price)
plt.grid(True)

# %%
import scipy.stats
plt.scatter(input_data.enginesize, input_data.price, s=50, c='blue', alpha=0.3, linewidths=1, edgecolors='blue')
plt.title('Engine and Price')
plt.xlabel('Engine')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
import numpy as np
#共分散を導出
print('共分散:', np.cov(input_data.price, input_data.enginesize))
#相関行列
print('相関行列:', np.corrcoef(input_data.price, input_data.enginesize))
# Out:
# 共分散: [[6.38217616e+07 2.90808158e+05]
#  [2.90808158e+05 1.73411392e+03]]
# 相関行列: [[1.        0.8741448]
#  [0.8741448 1.       ]]

# %%
import seaborn as sns
sns.jointplot(x='enginesize', y ='price', data=input_data)

# %%
x_list = pd.concat([input_data.price, input_data.enginesize, input_data.wheelbase, input_data.horsepower, input_data.carheight], axis=1)

sns.pairplot(x_list, kind='reg')

# %%
plt.figure(figsize=(12,9))
sns.heatmap(x_list.pct_change().corr(), annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
import statsmodels.api as sm
model = sm.OLS(input_data.price, sm.add_constant(input_data.enginesize))
results = model.fit()
print(results.summary())
print('p-values\n', results.pvalues)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     657.6
# Date:                Fri, 22 Aug 2025   Prob (F-statistic):           1.35e-65
# Time:                        03:08:56   Log-Likelihood:                -1984.4
# No. Observations:                 205   AIC:                             3973.
# Df Residuals:                     203   BIC:                             3979.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -8005.4455    873.221     -9.168      0.000   -9727.191   -6283.700
# ...

# %%
x_list
# Out:
#        price  enginesize  wheelbase  horsepower  carheight
# 0    13495.0         130       88.6         111       48.8
# 1    16500.0         130       88.6         111       48.8
# 2    16500.0         152       94.5         154       52.4
# 3    13950.0         109       99.8         102       54.3
# 4    17450.0         136       99.4         115       54.3
# ..       ...         ...        ...         ...        ...
# 200  16845.0         141      109.1         114       55.5
# 201  19045.0         141      109.1         160       55.5
# 202  21485.0         173      109.1         134       55.5
# 203  22470.0         145      109.1         106       55.5
# 204  22625.0         141      109.1         114       55.5
#
# [205 rows x 5 columns]

# %%
x_list2 = x_list.drop('price', axis=1)
price = input_data.price

# %%
model = sm.OLS(price, sm.add_constant(x_list2))
result = model.fit()
print(result.summary())
print('P値:\n', result.pvalues)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     218.2
# Date:                Fri, 22 Aug 2025   Prob (F-statistic):           9.29e-72
# Time:                        03:13:04   Log-Likelihood:                -1960.3
# No. Observations:                 205   AIC:                             3931.
# Df Residuals:                     200   BIC:                             3947.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.216e+04   5731.484     -5.611      0.000   -4.35e+04   -2.09e+04
# ...

# %%
#ダミー変数を作成
input_data2 = pd.get_dummies(input_data)
print(input_data2.columns.values)
# Out:
# ['car_ID' 'symboling' 'wheelbase' 'carlength' 'carwidth' 'carheight'
#  'curbweight' 'enginesize' 'boreratio' 'stroke' 'compressionratio'
#  'horsepower' 'peakrpm' 'citympg' 'highwaympg' 'price'
#  'CarName_Nissan versa' 'CarName_alfa-romero Quadrifoglio'
#  'CarName_alfa-romero giulia' 'CarName_alfa-romero stelvio'
#  'CarName_audi 100 ls' 'CarName_audi 100ls' 'CarName_audi 4000'
#  'CarName_audi 5000' 'CarName_audi 5000s (diesel)' 'CarName_audi fox'
#  'CarName_bmw 320i' 'CarName_bmw x1' 'CarName_bmw x3' 'CarName_bmw x4'
#  'CarName_bmw x5' 'CarName_bmw z4' 'CarName_buick century'
#  'CarName_buick century luxus (sw)' 'CarName_buick century special'
#  'CarName_buick electra 225 custom' 'CarName_buick opel isuzu deluxe'
#  'CarName_buick regal sport coupe (turbo)' 'CarName_buick skyhawk'
#  'CarName_buick skylark' 'CarName_chevrolet impala'
#  'CarName_chevrolet monte carlo' 'CarName_chevrolet vega 2300'
#  'CarName_dodge challenger se' 'CarName_dodge colt (sw)'
# ...

# %%
import numpy as np
from sklearn import linear_model, datasets
from sklearn.linear_model import LinearRegression

x_list3 = pd.concat([input_data2.enginesize, input_data2.wheelbase, input_data2.horsepower, input_data2.carheight, input_data2.doornumber_four, input_data2.fueltype_gas], axis=1)
price2 = input_data2.price

# %%
x_list3.head()
# Out:
#    enginesize  wheelbase  horsepower  carheight  doornumber_four  fueltype_gas
# 0         130       88.6         111       48.8            False          True
# 1         130       88.6         111       48.8            False          True
# 2         152       94.5         154       52.4            False          True
# 3         109       99.8         102       54.3             True          True
# 4         136       99.4         115       54.3             True          True

# %%
x_list3.dtypes
# Out:
# enginesize           int64
# wheelbase          float64
# horsepower           int64
# carheight          float64
# doornumber_four       bool
# fueltype_gas          bool
# dtype: object

# %%
#数値列をfloatに変換
for col in ['enginesize', 'wheelbase', 'horsepower', 'carheight']:
  x_list3[col] = pd.to_numeric(x_list[col])

#論理値列をintに変換
x_list3['doornumber_four'] = x_list3['doornumber_four'].astype(int)
x_list3['fueltype_gas'] = x_list3['fueltype_gas'].astype(int)

print(x_list3.dtypes)
print(x_list3.head())
# Out:
# enginesize           int64
# wheelbase          float64
# horsepower           int64
# carheight          float64
# doornumber_four      int64
# fueltype_gas         int64
# dtype: object
#    enginesize  wheelbase  horsepower  carheight  doornumber_four  fueltype_gas
# 0         130       88.6         111       48.8                0             1
# 1         130       88.6         111       48.8                0             1
# 2         152       94.5         154       52.4                0             1
# 3         109       99.8         102       54.3                1             1
# 4         136       99.4         115       54.3                1             1

# %%
model = sm.OLS(price2, sm.add_constant(x_list3))
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     151.2
# Date:                Fri, 22 Aug 2025   Prob (F-statistic):           4.05e-71
# Time:                        03:38:42   Log-Likelihood:                -1956.2
# No. Observations:                 205   AIC:                             3926.
# Df Residuals:                     198   BIC:                             3950.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const           -2.855e+04   6993.002     -4.083      0.000   -4.23e+04   -1.48e+04
# ...

# %%
print('P値:\n', result.pvalues)
# Out:
# P値:
#  const              6.447238e-05
# enginesize         9.029272e-13
# wheelbase          1.711651e-02
# horsepower         2.970865e-11
# carheight          2.934383e-01
# doornumber_four    4.901163e-01
# fueltype_gas       7.206785e-03
# dtype: float64

# %%
#多重共線性の確認
from statsmodels.stats.outliers_influence import *
num_cols = model.exog.shape[1]
num_cols
# Out:
# 7

# %%
vifs = [variance_inflation_factor(model.exog, i) for i in range(0, num_cols)]
pdv = pd.DataFrame(vifs, index=model.exog_names, columns=['VIF'])
print(pdv)
# Out:
#                         VIF
# const            850.900421
# enginesize         4.178532
# wheelbase          3.002954
# horsepower         3.562544
# carheight          2.073052
# doornumber_four    1.561073
# fueltype_gas       1.266018
